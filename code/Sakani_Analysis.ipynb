# %% [markdown]
# # EDA & ETL Part

# %%
#import needed packages
import os
import pandas as pd
import zipfile as zp
import sqlite3 as sql3
from dotenv import dotenv_values
from IPython.display import display

# %%
#importing our secrets from environment varibales
config = dotenv_values(".env")
os.environ['KAGGLE_USERNAME'] = config.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = config.get('KAGGLE_KEY')

# %%
#connecting to kaggle via api
from kaggle.api.kaggle_api_extended import KaggleApi
kgl_api = KaggleApi()
kgl_api.authenticate()

# %%
#here we declare where our paths is for (main data folder, kaggle dataset, extraction path)
data_path = '../data' #main data path
sqlite_path = '../db' #main db path
kaggle_dataset = 'majedalhulayel/sakani-projects-saudi-arabia' #kaggle dataset path
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /content/kaggle.json'
# sakani-projects-saudi-arabia.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#lets get the data
kgl_api.dataset_download_files(kaggle_dataset, data_path)

# %%
#unzip the dataset file and save to new dir
try:
  if os.path.exists(data_path): #if the data folder do exists enter here
    with zp.ZipFile(data_path+'/sakani-projects-saudi-arabia.zip') as data: #take from original path
      data.extractall(data_path) #uzip into the path if exists
      print(f"Done extracting all files to: {data_path}") #message
      
  else: #if the data folder doesn't exists enter here
    print(f'Creating new data folder: {data_path}\n') #message
    os.mkdir(data_path) #create new folder if not exists
    with zp.ZipFile(data_path+'/sakani-projects-saudi-arabia.zip') as data: #take from original path
      data.extractall(data_path) #unzip into the new path
    print(f"Done extracting all files to: {data_path}") #message
except:
  print("Invalid file")
# Out:
# Done extracting all files to: dataset

# %%
#lets play with the dataset
df = pd.read_csv("../data/Sakani Projects.csv")
df.head()
# Out:
#              id  location_lat  location_lon  city_id city_name_ar  \
# 0  project_1044     24.560109     46.519438       14       الرياض
# 1  project_1033     24.793165     46.633768       14       الرياض
# 2   project_681     24.058337     42.836919     3025         عفيف
# 3   project_378     18.446355     42.098271     3274        محايل
# 4   project_386     24.545443     44.404584      716     الدوادمي
#
#   city_name_en  region_id region_key region_name_ar region_name_en  ...  \
# 0    AR RIYADH          1     riyadh         الرياض         Riyadh  ...
# 1    AR RIYADH          1     riyadh         الرياض         Riyadh  ...
# 2         AFIF          1     riyadh         الرياض         Riyadh  ...
# 3      MUHAYIL          7       asir           عسير          'Asir  ...
# 4  AD DUWADIMI          1     riyadh         الرياض         Riyadh  ...
#
#    resource_id  resource_type  subsidizable          type  \
# 0         1044       projects             1  marketplaces
# 1         1033       projects             1  marketplaces
# 2          681       projects             1  marketplaces
# 3          378       projects             1  marketplaces
# 4          386       projects             1  marketplaces
#
#    under_construction_status  unit_types_0  unit_types_1  unit_types_2  \
# 0         under_construction     apartment           NaN           NaN
# 1         under_construction     apartment           NaN           NaN
# 2                        NaN          land           NaN           NaN
# 3                        NaN          land           NaN           NaN
# 4                        NaN          land           NaN           NaN
#
#   use_register_interest_flag  views_count
# 0                          0         1039
# 1                          0         1837
# 2                          0         5995
# 3                          0       372872
# 4                          0        50459
#
# [5 rows x 51 columns]

# %%
#lets see some info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  386 non-null    object
#  1   location_lat                        386 non-null    float64
#  2   location_lon                        386 non-null    float64
#  3   city_id                             386 non-null    int64
#  4   city_name_ar                        386 non-null    object
#  5   city_name_en                        386 non-null    object
#  6   region_id                           386 non-null    int64
#  7   region_key                          386 non-null    object
#  8   region_name_ar                      386 non-null    object
#  9   region_name_en                      386 non-null    object
#  10  region_order_sequence               386 non-null    int64
#  11  availability                        386 non-null    int64
#  12  available_units_count               386 non-null    int64
#  13  available_units_for_auctions_count  386 non-null    int64
#  14  basement                            386 non-null    int64
#  15  bookable                            386 non-null    int64
#  16  city_order_sequence                 386 non-null    int64
#  17  delegated_by_broker                 386 non-null    int64
#  18  developer_name                      173 non-null    object
#  19  driver_room                         386 non-null    int64
#  20  elevator                            386 non-null    int64
#  21  group_unit_id                       386 non-null    int64
#  22  maid_room                           386 non-null    int64
#  23  max_area                            386 non-null    float64
#  24  max_bathroom                        386 non-null    int64
#  25  max_bed_room                        386 non-null    int64
#  26  max_price                           386 non-null    float64
#  27  max_street_width                    386 non-null    int64
#  28  max_unit_age                        386 non-null    int64
#  29  min_area                            386 non-null    float64
#  30  min_bathroom                        386 non-null    int64
#  31  min_bed_room                        386 non-null    int64
#  32  min_price                           386 non-null    float64
#  33  min_street_width                    386 non-null    int64
#  34  min_unit_age                        386 non-null    int64
#  35  pool                                386 non-null    int64
#  36  project_name                        386 non-null    object
#  37  project_type                        386 non-null    object
#  38  promoted                            386 non-null    int64
#  39  publish                             386 non-null    int64
#  40  publish_date                        385 non-null    object
#  41  resource_id                         386 non-null    int64
#  42  resource_type                       386 non-null    object
#  43  subsidizable                        386 non-null    int64
#  44  type                                386 non-null    object
#  45  under_construction_status           169 non-null    object
#  46  unit_types_0                        386 non-null    object
#  47  unit_types_1                        27 non-null     object
#  48  unit_types_2                        3 non-null      object
#  49  use_register_interest_flag          386 non-null    int64
#  50  views_count                         386 non-null    int64
# dtypes: float64(6), int64(29), object(16)
# memory usage: 153.9+ KB

# %%
#lets deepdive into the dataset, to learn more
df.columns
# Out:
# Index(['id', 'location_lat', 'location_lon', 'city_id', 'city_name_ar',
#        'city_name_en', 'region_id', 'region_key', 'region_name_ar',
#        'region_name_en', 'region_order_sequence', 'availability',
#        'available_units_count', 'available_units_for_auctions_count',
#        'basement', 'bookable', 'city_order_sequence', 'delegated_by_broker',
#        'developer_name', 'driver_room', 'elevator', 'group_unit_id',
#        'maid_room', 'max_area', 'max_bathroom', 'max_bed_room', 'max_price',
#        'max_street_width', 'max_unit_age', 'min_area', 'min_bathroom',
#        'min_bed_room', 'min_price', 'min_street_width', 'min_unit_age', 'pool',
#        'project_name', 'project_type', 'promoted', 'publish', 'publish_date',
#        'resource_id', 'resource_type', 'subsidizable', 'type',
#        'under_construction_status', 'unit_types_0', 'unit_types_1',
#        'unit_types_2', 'use_register_interest_flag', 'views_count'],
#       dtype='object')

# %%
#unique unite types
df['unit_types_0'].unique()
# Out:
# array(['apartment', 'land', 'townhouse', 'villa'], dtype=object)

# %%
#unique project type
df['project_type'].unique()
# Out:
# array(['offplan_private_land', 'lands_moh_land', 'offplan_moh_land',
#        'readymade_private_land', 'readymade_moh_land',
#        'lands_private_land', 'advanced_self_construction'], dtype=object)

# %%
#unique developer name
df['developer_name'].unique()
# Out:
# array(['شركة المسكن المحدودة',
#        'شركة جود العمارة للتطوير والاستثمار العقاري', nan,
#        'الشركة الوطنية للإسكان', 'علي شار', 'الرائم للمقاولات',
#        'دار واعمار للاستثمار والتطوير العقاري',
#        'شركة الأثير للتطوير والاستثمار العقاري',
#        'شركة الفاف للتطوير العقاري', 'عبدالرحمن الراشد وأولاده', 'رتال',
#        'شركة الأولى لتطوير العقارات', 'ثبات المسكن العقارية',
#        'مكيون مطورون عمرانيون', 'شركة سمو العقارية مساهمة مدرجة',
#        'شركة درة الذهبية للتطوير العقاري',
#        'شركة مرسى البحار للمقاولات العامة', 'شركة أفاق الذهبية المحدودة',
#        'شركة عراب التمليك للتطوير العقاري',
#        'شركة ساطعة التعمير للتطوير والاستثمار العقاري',
#        'شركة تمكين للاستثمار و التطوير العقارى',
#        'فرع شركة خطى الخير للتشغيل والصيانة',
#        'شركة الحناكي للتطوير العقاري',
#        'شركة فيصل عبدالله بن سعيدان للاستثمار والتطويرالعقاري',
#        'شركة مساكن أفياء للتطوير والاستثمار العقاري',
#        'شركة محمد عبدالعزيز الحبيب وشركاؤه للاستثمار العقاري',
#        'شركة دور العقارية للعقارات المحدودة', 'مؤسسة لؤلؤة فرسان',
#        'شركة روض الخزامى للتطوير العقاري', 'شركة راج العقارية',
#        'وزارة الإسكان', 'شركة اعمار المدينة الاقتصادية',
#        'سعيد مسفر الغامدي للتطوير العقاري', 'سندس العقارية',
#        'شركة الأشغال العقارية', 'شركة قواعد الانماء للإنشاء والتطوير',
#        'شركة سكنا للتطوير العقاري', 'شركة تلال العقارية',
#        'شركة رافد للمقاولات عامة', 'شركة ازدهار للتطوير العقاري',
#        'شركة المنازل الذكية المحدودة',
#        'الشركة الوطنية للإسكان البناء المطور', 'شركة السليمان العقارية',
#        'شركة الضاحية المثالية للتطوير والاستثمار العقاري',
#        'شركة انشاء للتطوير والاستثمار العقاري',
#        'شركة أسوار المتحدة للتطوير العقاري',
#        'الشركة الخليجية للتعمير العقاري', 'شركه أفضل مسكن العقاريه',
#        'التحالف العقارية', 'الديار العربية للتطوير العقاري',
#        'أبراج ذهب للتطوير العقاري', 'مجموعة سلمان بن سعيدان للعقارات',
#        'شمائل الخليج للمقاولات', 'شركة جدارة العقارية',
#        'منازل العصرية للتطوير والاستثمار العقاري', 'ساني العامرية',
#        'مدى الشرقية للتطوير', 'عبر المملكة العقارية',
#        'مايا للتطوير والاستثمار العقاري', 'بن جارالله',
#        'التميمي للخدمات والصيانة العالمية',
#        'شركة المسكن الوافي للتطوير العقاري', 'صرح التقنية',
#        'لدن للإستثمار', 'سدين العربية للعقارات',
#        'حمد وأحمد محمد المزيني العقارية', 'شركة طراز العربية',
#        'الاستثمارات المبتكرة العقارية', 'شركة فضاء الاستثمار العقارية',
#        'شركة مسكن العربية للاستثمار والتطوير العقاري',
#        'شركة سمو الأصالة للتطوير والاستثمار العقاري',
#        'شركة أسيكو السعودية المحدودة', 'مؤسسة عنواني العقارية',
#        'شركة عبداللطيف جميل للأراضي المحدودة', 'شركة حجاج وشركاه',
#        'إدارة للتنمية والتطوير', 'التميمي للتجارة والتعهدات المحدودة',
#        'عنان العقارية', 'دار الأركان', 'الجبيل للتعمير', 'تحالف الزامل',
#        'شركة روانا للتطوير والاستثمار العقاري',
#        'شركة مرجان الشرقية للمقاولات العامة', 'شركة أزهر القابضة',
#        'الفايزية', 'تواصل الإمداد', 'الخماسية',
#        'شركة إسكان الحاكمية للاستثمار والتطوير العقاري',
#        'الشركة العقارية السعودية',
#        'شركة افاق التعمير للتطوير والاستثمار العقاري',
#        'شركة مدى المحدودة', 'بنائات العقارية', 'شركه رسو العقارية'],
#       dtype=object)

# %%
#unique region key
df['region_key'].unique()
# Out:
# array(['riyadh', 'asir', 'qassim', 'northern_borders', 'makkah', 'jizan',
#        'hail', 'madinah', 'tabuk', 'jawf', 'eastern_province', 'najran',
#        'bahah'], dtype=object)

# %%
#columns before drop
df.columns
# Out:
# Index(['id', 'location_lat', 'location_lon', 'city_id', 'city_name_ar',
#        'city_name_en', 'region_id', 'region_key', 'region_name_ar',
#        'region_name_en', 'region_order_sequence', 'availability',
#        'available_units_count', 'available_units_for_auctions_count',
#        'basement', 'bookable', 'city_order_sequence', 'delegated_by_broker',
#        'developer_name', 'driver_room', 'elevator', 'group_unit_id',
#        'maid_room', 'max_area', 'max_bathroom', 'max_bed_room', 'max_price',
#        'max_street_width', 'max_unit_age', 'min_area', 'min_bathroom',
#        'min_bed_room', 'min_price', 'min_street_width', 'min_unit_age', 'pool',
#        'project_name', 'project_type', 'promoted', 'publish', 'publish_date',
#        'resource_id', 'resource_type', 'subsidizable', 'type',
#        'under_construction_status', 'unit_types_0', 'unit_types_1',
#        'unit_types_2', 'use_register_interest_flag', 'views_count'],
#       dtype='object')

# %%
#rename some columns to more clean naming
df.rename(columns = {'under_construction_status':'construction_status','unit_types_0':'unit_type',\
                     'available_units_for_auctions_count':'available_auctions_units','available_units_count':'available_units'}, inplace=True)

# %%
#clean row-level data
df['developer_name'].fillna('لا يوجد مدخل', inplace=True)
df['publish_date'].ffill(inplace=True) #filling nan values with prev value
df['construction_status'].fillna('no entry', inplace=True)
df['location'] = df['location_lat'].astype(str) +','+ df['location_lon'].astype(str) #create new column to handle the lat,lot location

# %%
#un_wanted columns to delete
df.drop(['city_id','region_id','region_key','region_order_sequence','city_order_sequence','group_unit_id','promoted','unit_types_1', \
          'unit_types_2','type','resource_id','resource_type','subsidizable','max_street_width','max_unit_age','max_bathroom','driver_room', \
          'elevator','basement','delegated_by_broker','maid_room','min_bathroom','min_street_width','min_unit_age','pool','publish','use_register_interest_flag', \
          'location_lat', 'location_lon'], axis=1, inplace=True)

# %%
#columns after drop
df.columns
# Out:
# Index(['id', 'location_lat', 'location_lon', 'city_name_ar', 'city_name_en',
#        'region_name_ar', 'region_name_en', 'availability',
#        'available_units_count', 'available_units_for_auctions_count',
#        'bookable', 'developer_name', 'max_area', 'max_bed_room', 'max_price',
#        'min_area', 'min_bed_room', 'min_price', 'project_name', 'project_type',
#        'publish_date', 'under_construction_status', 'unit_types_0',
#        'views_count'],
#       dtype='object')

# %%
#here we see the dataset shape after cleaning
print(f"Dataset rows/columns: {df.shape}")

# %%
#len of the new columns
print(f'Length of Data (After Column Filtered): {len(df.columns)}')
# Out:
# Length of Data (After Column Filtered): 24

# %%
#lets save the new data to another file
print(f"Saving the new data to another file: {data_path}/cleaned_data.csv")
df.to_csv(data_path+'/cleaned_data.csv', index=False)

# %%
#lets load our cleand data into sqlite table
try:
  if os.path.exists(sqlite_path): #if the data folder do exists enter here
    engine = sql3.connect(config.get('SQLITE_DB'))
    df.to_sql(config.get('SQLITE_TABLE'), engine, index=False)
    print(f"Loading data into sqlite3 database ...!")

  else: #if the data folder doesn't exists enter here
    print(f'Creating new db folder: {sqlite_path}\n') #message
    os.mkdir(sqlite_path) #create new folder if not exists
    engine = sql3.connect(config.get('SQLITE_DB'))
    df.to_sql(config.get('SQLITE_TABLE'), engine, index=False)
    print(f"Loading data into sqlite3 database ...!")
except Exception as e:
  print(f"Invalid db ... \n{e}")

# %% [markdown]
# # Analysis Part

# %%
#lets see min/max units available
print(f"Minimum unit available: {df['available_units_count'].min()} units\
        \nMaximum unit available: {df['available_units_count'].max()} units\
        \nRegion with minimum projects: {df['region_name_en'].min()} city\
        \nRegion with maximum projects: {df['region_name_en'].max()} city\
        \nDeveloper with minimum projects: {df['developer_name'].min()} projects\
        \nDeveloper with maximum projects: {df['developer_name'].max()} projects")
# Out:
# Minimum unit available: 0 units
# Maximum unit available: 875 units
# Region with minimum projects: 'Asir city
# Region with maximum projects: Tabuk city
# Developer with minimum projects: أبراج ذهب للتطوير العقاري projects
# Developer with maximum projects: وزارة الإسكان projects

# %%
#lets see most developers with specific project requirements
spec_req = df.loc[(df['available_units_count'] > 50) & (df['available_units_count'] <=1000) & (df['min_area'] > 250) & (df['max_bed_room'] <= 2)]

# %%
#lets see the result
spec_req
# Out:
#               id  location_lat  location_lon                    city_name_ar  \
# 2    project_681     24.058337     42.836919                            عفيف
# 13   project_728     24.543460     43.958677                        الدوادمي
# 35   project_729     24.545152     43.902027                        الدوادمي
# 46   project_974     27.549589     47.726099              قرية (قرية العليا)
# 57   project_980     26.866979     47.119182              قرية (قرية العليا)
# 68   project_983     24.606367     43.601602                        الدوادمي
# 73   project_695     22.449905     39.097564  مدينة الملك عبدالله الاقتصادية
# 76   project_698      0.000000     22.442068  مدينة الملك عبدالله الاقتصادية
# 79   project_986     23.476689     44.373787                        القويعية
# 101  project_981     27.101857     47.015506              قرية (قرية العليا)
# 103  project_170     27.849254     42.455576                           بقعاء
# 124  project_990     28.651999     45.233108                      حفر الباطن
# 135  project_993     27.840814     45.982396                      حفر الباطن
# 136  project_384     28.036816     42.318835                           بقعاء
# 140  project_391     23.232996     45.552931                           الرين
# 165  project_561     26.365104     44.230823                        الشماسية
# 172  project_565     27.164083     46.996145              قرية (قرية العليا)
# 175  project_567     28.614934     44.053607                           رفحاء
# 176  project_562     23.924718     42.760833                            عفيف
# 180  project_584     22.620727     40.603987                            حاذة
# 181  project_589     25.523687     45.259725                           شقراء
# 182  project_585     29.302374     44.032425                           رفحاء
# 184  project_590     26.520287     47.337779              قرية (قرية العليا)
# 195  project_608     23.657414     42.580920                            عفيف
# 196  project_614     27.940933     46.907464              قرية (قرية العليا)
# 200  project_613     23.867212     42.700051                            عفيف
# 201  project_996     24.481550     46.707035                          الرياض
# 203  project_618     27.976281     47.023275                      حفر الباطن
# 207  project_619     23.834527     42.833243                            عفيف
# 209  project_637     27.103674     48.533783                        النعيرية
# 219  project_664     23.900181     42.853959                            عفيف
#
#                     city_name_en   region_name_ar    region_name_en  \
# 2                           AFIF           الرياض            Riyadh
# 13                   AD DUWADIMI           الرياض            Riyadh
# 35                   AD DUWADIMI           الرياض            Riyadh
# 46               QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 57               QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 68                   AD DUWADIMI           الرياض            Riyadh
# 73   King Abdullah Economic City      مكة المكرمة            Makkah
# 76   King Abdullah Economic City      مكة المكرمة            Makkah
# 79                    QUWAY'IYAH           الرياض            Riyadh
# 101              QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 103                        BAQ'A             حائل             Ha'il
# 124               HAFAR AL BATIN  المنطقة الشرقية  Eastern Province
# 135               HAFAR AL BATIN  المنطقة الشرقية  Eastern Province
# 136                        BAQ'A             حائل             Ha'il
# 140                      AR RAYN           الرياض            Riyadh
# 165               ASH SHIMASIYAH           القصيم            Qassim
# 172              QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 175                       RAFHA'  الحدود الشمالية  Northern Borders
# 176                         AFIF           الرياض            Riyadh
# 180                       HADHAH  المدينة المنورة           Madinah
# 181                      SHAQRA'           الرياض            Riyadh
# 182                       RAFHA'  الحدود الشمالية  Northern Borders
# 184              QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 195                         AFIF           الرياض            Riyadh
# 196              QARYAT AL 'ULYA  المنطقة الشرقية  Eastern Province
# 200                         AFIF           الرياض            Riyadh
# 201                    AR RIYADH           الرياض            Riyadh
# 203               HAFAR AL BATIN  المنطقة الشرقية  Eastern Province
# 207                         AFIF           الرياض            Riyadh
# 209                AN NU'AYRIYAH  المنطقة الشرقية  Eastern Province
# 219                         AFIF           الرياض            Riyadh
#
#      availability  available_units_count  available_units_for_auctions_count  \
# 2               1                     61                                   0
# 13              1                    353                                   0
# 35              1                     65                                   0
# 46              1                     86                                   0
# 57              1                    173                                   0
# 68              1                     54                                   0
# 73              1                    343                                   0
# 76              1                    230                                   0
# 79              1                    127                                   0
# 101             1                    183                                   0
# 103             1                     88                                  88
# 124             1                    135                                   0
# 135             1                    226                                   0
# 136             1                     59                                   0
# 140             1                    205                                   0
# 165             1                    267                                   0
# 172             1                    810                                   0
# 175             1                     91                                   0
# 176             1                    184                                   0
# 180             1                    367                                   0
# 181             1                    146                                   0
# 182             1                    336                                   0
# 184             1                    314                                   0
# 195             1                    102                                   0
# 196             1                    645                                 645
# 200             1                    438                                   0
# 201             1                    237                                   0
# 203             1                    455                                   0
# 207             1                    226                                   0
# 209             1                     79                                   0
# 219             1                     62                                   0
#
#      ...  max_price    min_area  min_bed_room  min_price  \
# 2    ...        0.0  556.500000             1        0.0
# 13   ...        0.0  580.871898             1        0.0
# 35   ...        0.0  595.500000             1        0.0
# 46   ...        0.0  424.050000             1        0.0
# 57   ...        0.0  600.000000             1        0.0
# 68   ...        0.0  586.538542             1        0.0
# 73   ...  1599680.0  427.400000             1   494908.0
# 76   ...   621428.0  280.000000             1   265650.0
# 79   ...        0.0  340.000000             1        0.0
# 101  ...        0.0  575.490000             1        0.0
# 103  ...        0.0  472.088256             1        0.0
# 124  ...        0.0  500.000000             1        0.0
# 135  ...        0.0  380.000000             1        0.0
# 136  ...        0.0  380.000000             1        0.0
# 140  ...        0.0  394.890000             1        0.0
# 165  ...        0.0  483.371000             1        0.0
# 172  ...        0.0  377.823000             1        0.0
# 175  ...        0.0  663.910000             1        0.0
# 176  ...        0.0  559.049000             1        0.0
# 180  ...        0.0  415.025000             1        0.0
# 181  ...        0.0  533.782549             1        0.0
# 182  ...        0.0  359.090000             1        0.0
# 184  ...        0.0  660.000000             1        0.0
# 195  ...        0.0  347.234000             1        0.0
# 196  ...        0.0  351.871000             1        0.0
# 200  ...        0.0  302.270000             1        0.0
# 201  ...   474271.0  336.910000             1   149960.0
# 203  ...        0.0  331.851332             1        0.0
# 207  ...        0.0  447.954000             1        0.0
# 209  ...        0.0  408.120000             1        0.0
# 219  ...        0.0  380.356000             1        0.0
#
#                                           project_name  \
# 2                                مخطط 879  - العيدانية
# 13                                   144 - وادي الرشاء
# 35                                         مخطط أ/ 228
# 46                           مخطط 119/20 - قرية العليا
# 57                              مخطط البويبيات - 47/18
# 68                                 مخطط الصالحية - 130
# 73             مدينة الملك عبدالله الاقتصادية - المروج
# 76      مدينة الملك عبدالله الاقتصادية - التالة جاردنز
# 79                                   مخطط 139 القويعية
# 101                                مخطط ش.ع 172 الرفاع
# 103                                       موقع بقعاء 2
# 124                           مخطط النظيم - 3/ح/د/1407
# 135                             مخطط أم قليب-54/ح/1410
# 136                               مشروع القليبة - حائل
# 140                                 مخطط العمق - الرين
# 165                                      مخطط الربيعية
# 172                         مخطط الفريدة - قرية العليا
# 175                                          هجرة رغوة
# 176                               مخطط الخالدية - عفيف
# 180                        مركز حاذه - المدينة المنورة
# 181                                     مخطط شقراء 151
# 182                                     ام غار الخشيبي
# 184  المخطط رقم ١٠/٧١ بمركز أم عقلاء بمحافظة قرية ا...
# 195                               مخطط الانسيات - عفيف
# 196                          مخطط ام كداد – حفر الباطن
# 200                                      مخطط عفيف 843
# 201                                   الأصالة - الرياض
# 203                                 معرج السوبان 21/18
# 207                                    مخطط 811 - عفيف
# 209                        مخطط الحسي 65/10 - النعيرية
# 219                           مخطط 293 - الفيضة - عفيف
#
#                    project_type  publish_date  under_construction_status  \
# 2                lands_moh_land    2022-06-30                   no entry
# 13               lands_moh_land    2022-06-30                   no entry
# 35               lands_moh_land    2022-06-30                   no entry
# 46               lands_moh_land    2022-06-30                   no entry
# 57               lands_moh_land    2022-06-30                   no entry
# 68               lands_moh_land    2022-06-30                   no entry
# 73           lands_private_land    2021-10-28                   no entry
# 76           lands_private_land    2021-10-28                   no entry
# 79               lands_moh_land    2022-06-30                   no entry
# 101              lands_moh_land    2022-06-30                   no entry
# 103              lands_moh_land    2021-08-27                   no entry
# 124              lands_moh_land    2022-06-30                   no entry
# 135              lands_moh_land    2022-06-30                   no entry
# 136              lands_moh_land    2021-08-27                   no entry
# 140              lands_moh_land    2021-08-27                   no entry
# 165              lands_moh_land    2021-08-27                   no entry
# 172              lands_moh_land    2021-08-27                   no entry
# 175              lands_moh_land    2021-08-27                   no entry
# 176              lands_moh_land    2021-08-27                   no entry
# 180              lands_moh_land    2021-08-27                   no entry
# 181              lands_moh_land    2021-08-27                   no entry
# 182              lands_moh_land    2021-08-27                   no entry
# 184              lands_moh_land    2021-08-27                   no entry
# 195              lands_moh_land    2021-08-27                   no entry
# 196              lands_moh_land    2021-08-27                   no entry
# 200              lands_moh_land    2021-08-27                   no entry
# 201  advanced_self_construction    2022-05-11         under_construction
# 203              lands_moh_land    2021-08-27                   no entry
# 207              lands_moh_land    2021-08-27                   no entry
# 209              lands_moh_land    2021-08-27                   no entry
# 219              lands_moh_land    2021-08-27                   no entry
#
#     unit_types_0 views_count
# 2           land        5995
# 13          land        5253
# 35          land        4290
# 46          land        8083
# 57          land        2306
# 68          land        2579
# 73          land       35880
# 76          land       35390
# 79          land        6091
# 101         land        1751
# 103         land        9124
# 124         land        4854
# 135         land        1728
# 136         land        4637
# 140         land        4027
# 165         land       60153
# 172         land        6168
# 175         land        1829
# 176         land        3698
# 180         land       29916
# 181         land       19405
# 182         land        1254
# 184         land        2199
# 195         land        1147
# 196         land        2130
# 200         land        1872
# 201        villa      155503
# 203         land        3403
# 207         land        1569
# 209         land        7583
# 219         land        3322
#
# [31 rows x 24 columns]
